# %%
from psychopy import visual, core, event
from psychopy.core import wait

# %%
win = visual.Window()

wait(2)

win.close()
# Out:
# 1.9051 	WARNING 	Monitor specification not found. Creating a temporary one...
